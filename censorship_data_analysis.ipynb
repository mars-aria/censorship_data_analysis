# %% [markdown]
# <a href="https://colab.research.google.com/github/mars-aria/censorship_data_analysis/blob/main/censorship_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What Effect Have U.S. Political Parties Had On State Censorship?

# %% [markdown]
# #### Report by: Marshanah Taylor | Co-Author(s): Ahmed Fillali and Christian Ikejiofor

# %% [markdown]
# # Research Question(s)

# %% [markdown]
# Throughout this data comparison analysis report, we investigate two main research questions:
#
# * Which political party has most influenced the banning of more books in the U.S.? AND
# * Which type of ban has been most prevalent in each state within the last few years?

# %% [markdown]
# # Problem Statement

# %% [markdown]
# According to the American Library Association (ALA), **censorship** is "the suppression of ideas and information that some individuals, groups, or government officials find objectionable or dangerous". However, despite being a sanctioned enactment of the law that seeks to protect young minds, censorship can have the adverse effect of creating barriers to knowledge and restricting access to information that is collectively valuable and beneficial to minorities and marginalized communities, especially for those who have been subject to historical erasure. Therefore, we endeavor to discover through our analysis: do more right-wing states ban books than left-wing states and which type of bans are targeted the most? It is our hypothesis that banned books are considered the most political in memory and educational institutions, particularly in the portions of the U.S. where the conservative party is predominant.

# %% [markdown]
# <br>
# ***
# <br>
#
# 1. <font color=#003A63>*As a team of Data Scholars, we formulated a research question that discusses **the banned book censorship attacks** and its prevalence by state.*</font>
#
# 3. <font color=#003A63>*Cleaning the dataset. Data cleaning is a critical step in the analysis. We explored the size of the data and the type of data present, and looked for gaps in the data and missing values that will affect the data analysis. Then we determined the next steps to ensure the data can be analyzed.*</font>
#
# 4. <font color=#003A63>*Analyzing the dataset. As Data Scientists, we used our knowledge of statistical methods to analyze the data and identify relationships between the variables. This step allowed our team to determine the best way to prepare the data for a machine learning algorithm and select the appropriate model(s) to explore the research question fully.*</font>
#
# 5. <font color=#003A63>*Interpreting and reporting the results of the data analysis and machine learning models. We communicate the results using charts, figures, and words to convey the findings to other researchers, policymakers, and business partners. We also identified the implications of the findings for future research studies.*</font>
#
# 6. <font color=#003A63>*Scientific research is reproducible. This means that the techniques used and the models created should be able to be used by other researchers to derive the same or similar results. This adds a layer of transparency to the research findings and permits peer review, identifying any gaps in the conclusions and celebrating the impact of the research performed. Additional team members and those outside the team should be able to run the code produced and arrive at similar results. To ensure the same results for machine learning models, we will consider using Random State, which generates the same partition of training, validation, and test data splits as opposed to randomly generated splits, which would yield similar but different results for consecutive runs.*</font>

# %% [markdown]
# ## Data Definitions
# The data should be described with a short synopsis that includes the source, the recency, and the location of the data when permitted.
#
# * **Index of School Book Bans | Source: PEN America** <br>
# Last Updated: 2022-2023. <br>
# https://pen.org/book-bans/2023-banned-book-list/<br>
# This dataset has only 2,000+ instances (2,235 to be exact). It contains information about books that have been banned during the censorship attacks. The following ten dimensions are included: Author, Title, Type of Ban, Secondary Author(s), Illustrator(s), Translator(s), State, District, Date of Challenge/Removal, and Origin of Challenge. It is an old dataset containing instances occurring from July 1, 2021 through June 30, 2022. The searchable database on the official website (reference url link above) has censorship data up until 2023. However, data from the year 2023 was not included in the data frame. In our comparison analysis, will only be utilizing the 2021-2022 dataset provided by the source.
#
# ### Additional Datasets of Interest
#
# * **Banned Book Dataset | Source: Kaggle** <br>
# Last Updated: February, 2025 <br>
# https://www.kaggle.com/datasets/chielerli/banned-book-dataset<br>
# This dataset has over 10,000 instances (17,441 to be exact). It contains only information about books that have been banned during the censorship attacks. The following five dimensions are included: Author, Title, Description, Genre, and Banned. It is being consistently updated as censorship cases continue to accumulate across the U.S.
#
# * **Book Censorship Database | Creator: Dr. Tasslyn Magnusson** <br>
# Last Updated: May 27, 2025. <br>
# https://www.everylibraryinstitute.org/book_censorship_database_magnusson?gad_source=1&gad_campaignid=6719281188&gbraid=0AAAAACxqR4WOCAOGootR4f6repuqa-lgL&gclid=Cj0KCQjwmK_CBhCEARIsAMKwcD6qCt4loQytpeyCQnZkEomUa-oxeYx7KEWs6SbKHxMZyAAk7cQGJKkaAu5EEALw_wcB<br>
# This is a database containing information about banned books. It was created through a joint partnership between The EveryLibrary Institute and Dr. Tasslyn Magnusson, an independent researcher focused on the networks, organizations, and individual actors who are leading book banning and book challenge efforts in our nation's school libraries and public libraries.
#
#
# * **Book Censorship Dataset | Source: Every Library Institute** <br>
# Last Updated: May 27, 2025. <br>
# https://docs.google.com/spreadsheets/d/1am1vKU3MR1209AanJVqySFtRYe3IiB1k/edit?gid=647219971#gid=647219971<br>
# This is the dataset version of the database created by Dr. Tasslyn Magnusson. It contains a total of 30 dimensions. The following dimensions included within the dataset are: Data_Entry_Date, Last_Updated, New_Book_Author, New_Book_Title, Series_Name, Book_Co_Author, Illustrators, Challenge_Type, Challenge_Init, Initial_Response, Challenge_Notes, Decision, Restrictions, Restriction_Details, Library_Type, Month, Year, State, Over_Seeing_Agency, City, County, Sch_Name, Lib_name, Police, Book_Status, Links1, Links2, Links3, Links4, and ID. It traces the book challenges and bans in America dating back to December 15, 2023. It is continually being updated as the case continues.

# %% [markdown]
# ## Data Collection:

# %% [markdown]
# Our data collection process begins with identifying a reliable and accurate data source and using tools to download the dataset for examination. The drive is mounted and imported to Colab, creating a link to the data source. Next, the necessary libraries are imported which contain pre-written code which perform specific tasks. Python has several libraries which are powerful tools from data analysis and visualization. Once the dataset was loaded and the libraries imported, the dataset was read and the dataframe created. After checking the data, we began the data cleaning process.

# %% [markdown]
# ## Examine the dataset

# %% [markdown]
# ### Import libraries

# %%
# Import the libraries
import numpy as np                  # Scientific Computing
import pandas as pd                 # Data Analysis
import matplotlib.pyplot as plt     # Plotting
import matplotlib.patches as mpatches
import seaborn as sns               # Statistical Data Visualization

# Let's make sure pandas returns all the rows and columns for the dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Force pandas to display full numbers instead of scientific notation
# pd.options.display.float_format = '{:.0f}'.format

# Library to suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the dataset

# %%
# Read the dataset
path_2 = pd.read_csv('/content/sample_data/banned_books_dataset_2.csv')

# Create the Dataframes
DataFrame2 = pd.DataFrame(path_2)

# %% [markdown]
# Inside the parentheses, we can write the number of elements that we want to see.
# If we leave it blank, it will show the first five elements.
# If we write 7 inside of the parentheses, it will show the first 7 elements of the dataframe.

# %%
# Display the first seven rows of the dataframe
DataFrame2.head(8)
# Out:
#                Unnamed: 0          Unnamed: 1  \
# 0                     NaN                 NaN
# 1                  Author               Title
# 2  Àbíké-Íyímídé, Faridah       Ace of Spades
# 3      Acevedo, Elizabeth  Clap When You Land
# 4      Acevedo, Elizabeth          The Poet X
# 5      Acevedo, Elizabeth          The Poet X
# 6      Acevedo, Elizabeth          The Poet X
# 7      Acevedo, Elizabeth          The Poet X
#
#              PEN AMERICA'S INDEX OF SCHOOL BOOK BANS           Unnamed: 3  \
# 0  PEN America's Index of School Book Bans lists ...                  NaN
# 1                                        Type of Ban  Secondary Author(s)
# 2                 Banned in Libraries and Classrooms                  NaN
# 3                               Banned in Classrooms                  NaN
# 4                                Banned in Libraries                  NaN
# 5                 Banned in Libraries and Classrooms                  NaN
# ...

# %% [markdown]
# Checking last elements of the DataFrame with .tail() method
# There is also a method to see the see last n number of elements.
# The method is called .tail().
# The same rule is also applied here. If we leave the parentheses blank, it will be set as 5, if we write 7 inside of the parentheses, it will show the last 7 elements of the dataframe.

# %%
# Display the last seven rows of the dataframe
DataFrame2.tail(8)
# Out:
#                   Unnamed: 0  \
# 2526       Yousafzai, Malala
# 2527         Zabarsky, Jessi
# 2528  Zeldis McDonough, Yona
# 2529            Zia, Farhana
# 2530         Ziemke, Kristin
# 2531              Zoboi, Ibi
# 2532              Zoboi, Ibi
# 2533        Zunon, Elizabeth
#
#                                              Unnamed: 1  \
# 2526                              Malala's Magic Pencil
# 2527                                         Witchlight
# 2528      Who Was Sojourner Truth? (Who was...? Series)
# 2529                             The Garden of My Imaan
# 2530  Read the World: Rethinking Literacy for Empath...
# 2531                                    American Street
# 2532  Black Enough: Stories of Being Young & Black i...
# 2533  Grandpa Cacao: A Tale of Chocolate, from Farm ...
#
#      PEN AMERICA'S INDEX OF SCHOOL BOOK BANS       Unnamed: 3     Unnamed: 4  \
# 2526                    Banned in Classrooms              NaN      Kerascoët
# ...

# %% [markdown]
# * State the shape of the dataframe :
#   - How many rows does the dataframe have?
#   - How many columns does the dataframe have?
#   - What is the total number of datapoints expected in the dataset (rows x columns)?

# %%
# display the dimensions of the data
# This is the number of rows and columns in the data
DataFrame2.shape # Rows = 2534, Columns = 10, Datapoints (2534 x 10)
# Out:
# (2534, 10)

# %% [markdown]
# ### Data Types
# * The main data types in Pandas dataframes are `object`, `float`, `int64`, `bool` and `datetime64`. In order to understand each attribute of the data, it is always good to know the data type of each column.
#
# ##### `.info()` method
# * This method prints information about a DataFrame including the index `dtype` and column dtypes, non-null values and memory usage.

# %%
# Let's check the basic information about the dataset
DataFrame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2534 entries, 0 to 2533
# Data columns (total 10 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               2533 non-null   object
#  1   Unnamed: 1                               2533 non-null   object
#  2   PEN AMERICA'S INDEX OF SCHOOL BOOK BANS  2534 non-null   object
#  3   Unnamed: 3                               167 non-null    object
#  4   Unnamed: 4                               547 non-null    object
#  5   Unnamed: 5                               28 non-null     object
#  6   Unnamed: 6                               2533 non-null   object
#  7   Unnamed: 7                               2533 non-null   object
#  8   Unnamed: 8                               2533 non-null   object
#  9   Unnamed: 9                               2533 non-null   object
# dtypes: object(10)
# ...

# %% [markdown]
# ### Observations of the Data Set
# Describe the dataset. How many rows and columns are there? What are the data types? Based on the number of expected data points, and those listed by the `.info()` method, how many missing (null) values are there?
#
# The number of non-null values does not match the total number expected based on the number of rows in the dataframe. This indicates the presence of missing values that will need further investigation.

# %% [markdown]
# # Data Cleaning:

# %% [markdown]
# ## Data Analysis and Preparation
# The steps of analysis and preparation of the data for statistical modeling has several steps:
# 1. Check dimensions of the dataframe to determine the number rows and columns. This increases understanding of the data structure and size.
# 2. Check data types, ensuring the data types are correct. Refer data definitions to validate the results. For example dates including year, month, and day should be updated from integers or strings to `datetime` for ease of use in time series analysis.
# 3. Update data types based on the business definition, changing the data types as per requirement.
# 4. Using Python and Numpy methods, examine the summary statistics. This assists in determination of the data scale, including the relative minima and maxima for the range. The distribution of data with early determination of skewness or kurtosis are also visible for outliers in the data.
# 5. Checking for missing values that may cause noise in machine learning models and abberations in visualizations.
# 6. Study the correlation between data variables for key insights and future feature engineering.
# 7. Detection of outliers that may contribute to the skewness in data or add to the kurtosis affecting the data ranges.

# %% [markdown]
# ### Headers Update and Map New Column
#
# >
# - To aid in analysis and visualization add a new columns as needed. For instance instead of an entire state name, add a column that has a two letter abbreviation for the state.
# - The list of headers requires standardization, these will be updated ensure uniformity.
# - Update ALL CAPS or all lowercase to the appropriate case. These can be updated to Title Case.

# %%
# Let's Update the Headers for Syntax Consistency
# DataFrame2 = DataFrame2.rename(columns={'currentColumnName':'newColumnName', 'nextCurrentColumnName':'nextNewColumnName'})

# Renamed the columns to their correct names
DataFrame2.columns = DataFrame2.iloc[1]

DataFrame2.columns

# Let's view the new columns and update the variable
# Pass the columns to the variable: Use the variable = DataFrame.columns method

# Call the variable to see the contents
# Out:
# Index(['Author', 'Title', 'Type of Ban', 'Secondary Author(s)',
#        'Illustrator(s)', 'Translator(s)', 'State', 'District',
#        'Date of Challenge/Removal', 'Origin of Challenge'],
#       dtype='object', name=1)

# %%
# Removed the first two rows

DataFrame2 = DataFrame2.iloc[2:]

DataFrame2.head()
# Out:
# 1                  Author               Title  \
# 2  Àbíké-Íyímídé, Faridah       Ace of Spades
# 3      Acevedo, Elizabeth  Clap When You Land
# 4      Acevedo, Elizabeth          The Poet X
# 5      Acevedo, Elizabeth          The Poet X
# 6      Acevedo, Elizabeth          The Poet X
#
# 1                         Type of Ban Secondary Author(s) Illustrator(s)  \
# 2  Banned in Libraries and Classrooms                 NaN            NaN
# 3                Banned in Classrooms                 NaN            NaN
# 4                 Banned in Libraries                 NaN            NaN
# 5  Banned in Libraries and Classrooms                 NaN            NaN
# 6        Banned Pending Investigation                 NaN            NaN
#
# 1 Translator(s)         State                                    District  \
# 2           NaN       Florida         Indian River County School District
# 3           NaN  Pennsylvania                Central York School District
# ...

# %%
print(DataFrame2['State'].unique())
# Out:
# ['Florida' 'Pennsylvania' 'New York' 'Texas' 'Virginia' 'Michigan'
#  'Tennessee' 'Mississippi' 'Wisconsin' 'Idaho' 'Georgia' 'Iowa' 'Kansas'
#  'Oklahoma' 'Missouri' 'Ohio' 'Oregon' 'Rhode Island' 'South Dakota'
#  'Indiana' 'Vermont' 'North Carolina' 'Minnesota' 'Utah' 'Maryland'
#  'Washington' 'Alaska' 'Illinois' 'Maine' 'South Carolina' 'Arkansas'
#  'New Jersey']

# %%
# Total number of states in Dataframe2

DataFrame2['State'].nunique()
# Out:
# 32

# %%
# Total number of ban types

DataFrame2['Type of Ban'].nunique()
# Out:
# 4

# %%
# Counts total number of bans per state in DataFrame2

DataFrame2['State'].value_counts()
# Out:
# State
# Texas             801
# Florida           566
# Pennsylvania      458
# Tennessee         349
# Oklahoma           43
# Michigan           41
# Kansas             30
# Wisconsin          29
# Missouri           27
# Idaho              26
# Georgia            23
# Mississippi        22
# Virginia           19
# Indiana            18
# North Carolina     16
# New York           13
# Utah               12
# Iowa                8
# Illinois            5
# South Dakota        5
# Washington          5
# Ohio                4
# New Jersey          3
# Oregon              1
# Minnesota           1
# Vermont             1
# Rhode Island        1
# Maryland            1
# Alaska              1
# Maine               1
# South Carolina      1
# Arkansas            1
# Name: count, dtype: int64

# %%
# Shows only the total number of bans per state greater than 1 in DataFrame2

DataFrame2['State'].value_counts(dropna=False)[DataFrame2['State'].value_counts(dropna=False) > 1]
# Out:
# State
# Texas             801
# Florida           566
# Pennsylvania      458
# Tennessee         349
# Oklahoma           43
# Michigan           41
# Kansas             30
# Wisconsin          29
# Missouri           27
# Idaho              26
# Georgia            23
# Mississippi        22
# Virginia           19
# Indiana            18
# North Carolina     16
# New York           13
# Utah               12
# Iowa                8
# Illinois            5
# South Dakota        5
# Washington          5
# Ohio                4
# New Jersey          3
# Name: count, dtype: int64

# %%
# Number of unique states mentioned at least once

unique_states = DataFrame2['State'].nunique(dropna=True)
print(unique_states)
# Out:
# 32

# %%
# Retrieves all unique, non-null states in the data frame
unique_states = DataFrame2['State'].dropna().unique()

# Creates a Series where each unique state has a count of 1
state_presence = pd.Series(1, index=sorted(unique_states))

# Title of List
print("Banned Book States: \n")
print(state_presence)

# Returns the total number of states in DataFrame2 at the end
print(f"\nTotal number in the U.S.: {state_presence.sum()} out of 50 states")
# Out:
# Banned Book States:
#
# Alaska            1
# Arkansas          1
# Florida           1
# Georgia           1
# Idaho             1
# Illinois          1
# Indiana           1
# Iowa              1
# Kansas            1
# Maine             1
# Maryland          1
# Michigan          1
# Minnesota         1
# Mississippi       1
# Missouri          1
# New Jersey        1
# New York          1
# North Carolina    1
# Ohio              1
# Oklahoma          1
# Oregon            1
# Pennsylvania      1
# Rhode Island      1
# South Carolina    1
# South Dakota      1
# Tennessee         1
# Texas             1
# Utah              1
# Vermont           1
# Virginia          1
# Washington        1
# Wisconsin         1
# dtype: int64
#
# Total number in the U.S.: 32 out of 50 states

# %%
# Counts the total amount of each ban type in the DataFrame2

DataFrame2['Type of Ban'].value_counts()
# Out:
# Type of Ban
# Banned Pending Investigation          1375
# Banned in Classrooms                   487
# Banned in Libraries                    337
# Banned in Libraries and Classrooms     333
# Name: count, dtype: int64

# %%
# Displays the total number of book bans per state in DataFrame2 side-by-side

bans_by_state = DataFrame2['State'].value_counts() # Counts total bans per State
print("Total number of book bans per state: \n")
print(bans_by_state)
# Out:
# Total number of book bans per state:
#
# State
# Texas             801
# Florida           566
# Pennsylvania      458
# Tennessee         349
# Oklahoma           43
# Michigan           41
# Kansas             30
# Wisconsin          29
# Missouri           27
# Idaho              26
# Georgia            23
# Mississippi        22
# Virginia           19
# Indiana            18
# North Carolina     16
# New York           13
# Utah               12
# Iowa                8
# Illinois            5
# South Dakota        5
# Washington          5
# Ohio                4
# New Jersey          3
# Oregon              1
# Minnesota           1
# Vermont             1
# Rhode Island        1
# Maryland            1
# Alaska              1
# Maine               1
# South Carolina      1
# Arkansas            1
# Name: count, dtype: int64

# %%
# Calculates the states with the maximum and minimum number of bans in the U.S. during 2021-2022.

highest_bans_state = bans_by_state.idxmax()
highest_bans_count = bans_by_state.max()

lowest_bans_state = bans_by_state.idxmin()
lowest_bans_count = bans_by_state.min()

print(f"State with the highest number of book bans in the U.S.: {highest_bans_state} ({highest_bans_count} bans total).")
print(f"State with the lowest number of book bans in the U.S.: {lowest_bans_state} (only {lowest_bans_count} ban total).") # first state listed with the lowest number of bans
# Out:
# State with the highest number of book bans in the U.S.: Texas (801 bans total).
# State with the lowest number of book bans in the U.S.: Oregon (only 1 ban total).

# %%
# Filters only states with more than 1 ban
more_than_1_ban = bans_by_state[bans_by_state > 1]

# Finds the lowest number of bans (greater than 1)
lowest_bans_state = more_than_1_ban.idxmin()
lowest_bans_count = more_than_1_ban.min()

print(f"State with the lowest number of book bans (excluding states with only 1 ban): {lowest_bans_state} ({lowest_bans_count} bans total).")
# Out:
# State with the lowest number of book bans (excluding states with only 1 ban): New Jersey (3 bans total).

# %%
# Calculates the mean and median of book bans across all states
mean_bans = bans_by_state.mean()
median_bans = bans_by_state.median()

print(f"Mean of Book Bans: {mean_bans:.2f}")
print(f"Median of Book Bans: {median_bans}")
# Out:
# Mean of Book Bans: 79.12
# Median of Book Bans: 12.5

# %%
# Groups by State and Type of Ban and counts the number of bans per state
bans_by_state_and_type = DataFrame2.groupby(['State', 'Type of Ban']).size().reset_index(name='Ban Count')

print(bans_by_state_and_type)
# Out:
#              State                         Type of Ban  Ban Count
# 0           Alaska  Banned in Libraries and Classrooms          1
# 1         Arkansas  Banned in Libraries and Classrooms          1
# 2          Florida        Banned Pending Investigation        366
# 3          Florida                Banned in Classrooms          1
# 4          Florida                 Banned in Libraries         73
# 5          Florida  Banned in Libraries and Classrooms        126
# 6          Georgia        Banned Pending Investigation          1
# 7          Georgia                Banned in Classrooms          1
# 8          Georgia                 Banned in Libraries          8
# 9          Georgia  Banned in Libraries and Classrooms         13
# 10           Idaho                 Banned in Libraries          1
# 11           Idaho  Banned in Libraries and Classrooms         25
# 12        Illinois        Banned Pending Investigation          1
# ...

# %%
# Calculates the mean and median of book bans per state for each ban type
mean_median_by_type = bans_by_state_and_type.groupby('Type of Ban')['Ban Count'].agg(['mean', 'median'])

print(mean_median_by_type)
# Out:
#                                          mean  median
# Type of Ban
# Banned Pending Investigation        68.750000     9.0
# Banned in Classrooms                37.461538     1.0
# Banned in Libraries                 17.736842     3.0
# Banned in Libraries and Classrooms  13.320000     3.0

# %%
# Counts the number of occurrences for each ban type
type_counts = DataFrame2['Type of Ban'].value_counts()

print("Ban Type Frequency: \n")
print(type_counts)
# Out:
# Ban Type Frequency:
#
# Type of Ban
# Banned Pending Investigation          1375
# Banned in Classrooms                   487
# Banned in Libraries                    337
# Banned in Libraries and Classrooms     333
# Name: count, dtype: int64

# %% [markdown]
# #### Missing Values Imputation Methods
# Missing value imputation is a technique used to replace missing values in a dataset with estimated values. This is done to preserve the data and make it more complete for analysis. There are many different imputation techniques available, each with its own advantages and disadvantages.
#
# Some of the most common imputation techniques include:
#
# - Mean imputation: This is the simplest imputation technique. It involves replacing missing values with the mean of the observed values for that variable. This is a quick and easy technique, but it can introduce bias if the distribution of the missing values is not normal. Mean as a measure is greatly affected by outliers or if the distribution of the data or column is not normally-distributed. Therefore, it’s wise to first check the distribution of the column before deciding if to use a mean imputation or median imputation.
# - Median imputation: This is similar to mean imputation, but it replaces missing values with the median of the observed values for that variable. This is a more robust technique than mean imputation, but it can still introduce bias if the distribution of the missing values is not symmetric.
# - Mode imputation: This replaces missing values with the most frequent value of the observed values for that variable. This is a simple technique that is not as likely to introduce bias as mean or median imputation. However, it can be problematic if the most frequent value is not representative of the overall distribution of the data.
# - Regression imputation: This technique uses a regression model to predict the missing values. The model is trained on the observed values for the variable with missing values and other related variables. The predicted values are then used to replace the missing values. This is a more sophisticated technique than the other imputation techniques, but it can be more time-consuming and computationally expensive.
#
# The best imputation technique to use depends on the specific dataset and the analysis that you are trying to do. In general, it is a good idea to try multiple imputation techniques and see which one works best for your data.
#
# - Mean imputation works better if the distribution is normally-distributed or has a Gaussian distribution, while median imputation is preferable for skewed distribution(be it right or left)
# - If the values are not normally distributed and show some skewness toward extreme high values or extreme low values consider using the median for imputation. The median is not suceptible to skewness in the data.
# - Sometimes it is advisable to drop the columns when the NULL values are significantly more than the other values present.

# %%
# Returns the sum of null values in each column

print(DataFrame2.isnull().sum())
# Out:
# 1
# Author                          0
# Title                           0
# Type of Ban                     0
# Secondary Author(s)          2366
# Illustrator(s)               1986
# Translator(s)                2505
# State                           0
# District                        0
# Date of Challenge/Removal       0
# Origin of Challenge             0
# dtype: int64

# %%
# Returns the percentage of missing null values in each column

missing(DataFrame2)
# Out:
# Percentage of missing values in the dataset:
#  1
# Translator(s)                98.93
# Secondary Author(s)          93.44
# Illustrator(s)               78.44
# Author                        0.00
# Title                         0.00
# Type of Ban                   0.00
# State                         0.00
# District                      0.00
# Date of Challenge/Removal     0.00
# Origin of Challenge           0.00
# dtype: float64

# %%
# Removes columns not needed for data visualization

DataFrame2 = DataFrame2.drop(labels=None, axis=0, index=None, columns=["Author", "Secondary Author(s)", "Title", "Illustrator(s)", "Translator(s)", "District", "Origin of Challenge", "Date of Challenge/Removal"], level=None, inplace=False, errors='raise')

# %%
DataFrame2.head()
# Out:
# 1                         Type of Ban         State
# 2  Banned in Libraries and Classrooms       Florida
# 3                Banned in Classrooms  Pennsylvania
# 4                 Banned in Libraries       Florida
# 5  Banned in Libraries and Classrooms      New York
# 6        Banned Pending Investigation         Texas

# %%
# Checks the null count again
DataFrame2.isnull().sum()
# Out:
# 1
# Type of Ban    0
# State          0
# dtype: int64

# %% [markdown]
# ### Observations
# - How many missing values are there?
# - Are these concentrated in specific rows or columns? How does this affect the analysis?
# - Based on the information that is present, how should the missing values be handled? How will this affect the analysis?

# %%
# Makes a copy of DataFrame2 before manipulation
# Syntax: DataFrameOG = workingDF
DataFrame2 = DataFrame2.copy()

# %%
# Checks the new dataframe with .head() method.
DataFrame2.head()
# Out:
# 1                         Type of Ban         State
# 2  Banned in Libraries and Classrooms       Florida
# 3                Banned in Classrooms  Pennsylvania
# 4                 Banned in Libraries       Florida
# 5  Banned in Libraries and Classrooms      New York
# 6        Banned Pending Investigation         Texas

# %%
# Checks a specific column in the new dataframe with .head() method.
DataFrame2['Type of Ban'].head()
# Out:
# 2    Banned in Libraries and Classrooms
# 3                  Banned in Classrooms
# 4                   Banned in Libraries
# 5    Banned in Libraries and Classrooms
# 6          Banned Pending Investigation
# Name: Type of Ban, dtype: object

# %% [markdown]
# ### Observations on Missing Values
# Include observations on the methods used to update the dataFrame for missing values and complete the cleaning process.  Did you use a method to impute the missing data? Did you choose to drop null or NaN values? Did you split the dataset to create subsets? Use this space to explain the techniques, approach, and reasoning.

# %% [markdown]
# # Data Exploration:

# %% [markdown]
# ## Summary Statistics

# %% [markdown]
# ##### `.describe()` method
#
# * This method is used to get a summary of numeric values in your dataset.
# * It calculates the mean, standard deviation, minimum value, maximum value, 1st percentile, 2nd percentile, 3rd percentile of the columns with numeric values.
# * It also counts the number of variables in the dataset.

# %%
## Describe the descriptive stats
DataFrame2.describe()
# Out:
# 1                        Type of Ban  State
# count                           2532   2532
# unique                             4     32
# top     Banned Pending Investigation  Texas
# freq                            1375    801

# %%
# Counts total bans per state
ban_counts_by_state = DataFrame2.groupby('State').size()

# Calculates the statistics
min_bans = ban_counts_by_state.min()
max_bans = ban_counts_by_state.max()
median_bans = ban_counts_by_state.median()
mean_bans = ban_counts_by_state.mean()

# Displays the results together
print(f"Minimum number of bans (among all states): {min_bans}")
print(f"Maximum number of bans (among all states): {max_bans}")
print(f"Median of bans (across all states): {median_bans}")
print(f"Mean of bans (across all states): {mean_bans:.2f}")
# Out:
# Minimum number of bans (among all states): 1
# Maximum number of bans (among all states): 801
# Median of bans (across all states): 12.5
# Mean of bans (across all states): 79.12

# %% [markdown]
# #### Observations of Descriptive Statistics
# The following are some observations about each table: <br>
# DataFrame:
#  * What are the minimum and maximum values?
#  * What are the mean values for the data?
#  * Are the mean and median values close to each other? If so this could indicate a normal distribution of the data. If not, this could indicate skewness in the data. If the mean is smaller than the median the values are likely skewed left, toward the minimum value. If the mean is larger than the median then there is skewness to the right indicating more high values in the data distribution.
#  * What are the quartile ranges for the data? What value is the 25th percentile of the data? What value is the 75th percentile of the data?
#  * How does the standard deviation for the data compare to the mean? High values for the standard deviation indicate a large variation in the data and likely a wide spread of the data across the range from minimum to maximum.<br>

# %% [markdown]
# # Data Visualization 1 (Exploration Results)

# %% [markdown]
# ### Research Question: Which political party has most influenced the banning of more books in the U.S.?
# This visualization technique describes the initial research question by showcasing the distribution of books per state that were banned between the years 2021 and 2022. It also utilizes color to illustrate the political affiliation of each censorship state in the U.S. at the time. In this context, a top censorship state is classified as a state that has had more than one occurrence of book banning appear in the dataset.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# List of states
bars = ["Texas", "Florida", "Pennsylvania", "Tennessee", "Oklahoma",
        "Michigan", "Kansas", "Wisconsin", "Missouri", "Idaho",
        "Georgia", "Mississippi", "Virginia", "Indiana", "North Carolina",
        "New York", "Utah", "Iowa", "Illinois", "South Dakota",
        "Washington", "Ohio", "New Jersey"]

# Number of observations
bar_heights = [801, 566, 458, 349, 43, 41, 30, 29, 27, 26,
               23, 22, 19, 18, 16, 13, 12, 8, 5, 5, 5, 4, 3]

# List of colors you pick directly
# Use 'red' for Republican and 'blue' for Democrat
bar_colors = ["red", "red", "blue", "red", "red",
              "blue", "red", "blue", "red", "red",
              "blue", "red", "blue", "red", "red",
              "blue", "red", "red", "blue", "red",
              "blue", "red", "blue"]

# Plot
plt.figure(figsize=(14, 6))
x_pos = np.arange(len(bars))
plt.bar(x_pos, bar_heights, color=bar_colors)

# Labels and title
plt.title('Political Affiliations of Top Book-Banning U.S. States [2021-2022]', fontweight='bold', fontsize=18)
plt.xlabel('State', fontweight='bold', fontsize=15)
plt.ylabel('Total Number of Bans', fontweight='bold', fontsize=15)

# X-ticks
plt.xticks(x_pos, bars, rotation=45, fontsize=10)

# Legend
red_patch = mpatches.Patch(color='red', label='Republican')
blue_patch = mpatches.Patch(color='blue', label='Democrat')
plt.legend(handles=[red_patch, blue_patch], title='Party', loc='upper right')

plt.show()

# %% [markdown]
# ### Summary of the Findings

# %% [markdown]
# #### Observations: Bar Chart
# From this visualization, we observe the following:
#   - The top 5 censorship states were Texas, Florida, Pennsylvania, Tennessee, and Oklahoma.
#   - Among the top five censorship states, 4 out of 5 were Republican (right-wing/red).
#   - Texas had the most recorded cases of book bannings in the PENN America dataset, appearing 801 times within the span of 2 years.
#   - Majority of the U.S. states participating in censorship were Republican, with only 6 out of 23 holding a Democratic affliation.
#   - States like Illinois, South Dakota, Washington, Ohio, and New Jersey only banned 3 to 5 books between 2021 and 2022.

# %% [markdown]
# # Data Visualization 2 (Exploration Results)

# %% [markdown]
# ### Research Question: Which type of ban has been most prevalent in each state within the last few years?
# This visualization technique describes the secondary research question by showcasing the distribution of ban types per state between the years 2021 and 2022. It also utilizes color to illustrate the difference in ban type for each censorship state in the U.S.

# %%
# Splits the 'Type of Ban' column into multiple rows
df_exploded = DataFrame2.copy()
df_exploded['Type of Ban'] = df_exploded['Type of Ban'].str.split(', ')
df_exploded = df_exploded.explode('Type of Ban')

# %%
# Renames two of the ban types for the sake of simplicity
DataFrame2['Type of Ban'] = DataFrame2['Type of Ban'].replace({
    'Banned in Libraries and Classrooms': 'Banned in Both',
    'Banned Pending Investigation': 'Pending Book Bans'
})

# %%
# Groups by State and Type of Ban
totals_by_state = DataFrame2.groupby(['State', 'Type of Ban']).size().reset_index(name='Total Bans')

# Pivots data for stacked bars
pivot_df = totals_by_state.pivot(index='State', columns='Type of Ban', values='Total Bans').fillna(0)

# Sorts states by total bans (for nicer visualization)
pivot_df['Total'] = pivot_df.sum(axis=1)
pivot_df = pivot_df.sort_values('Total', ascending=False).drop(columns='Total')

# Plots the data as a stacked bar chart
pivot_df.plot(kind='bar', stacked=True, figsize=(16, 8), colormap='tab20')

plt.title('Frequency Distribution of Book Ban Types in U.S. States [2021-2022]', fontweight='bold', fontsize=20)
plt.xlabel('State', fontweight='bold', fontsize=18)
plt.ylabel('Total Number of Bans', fontweight='bold', fontsize=18)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=16)
plt.legend(title='Type of Ban', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Summary of the Findings

# %% [markdown]
# #### Observations: Stacked Bar Chart
# From this visualization, we observe the following:
#   - The censorship state with the most books banned in libraries: Texas
#   - The censorship state with the most books banned in classrooms: Pennsylvania
#   - The censorship state with the most books banned in both libraries and classrooms: Florida
#   - The censorship state with the most pending book ban case investigations: Texas

# %% [markdown]
# # Analyzing the Results (Conclusion)

# %% [markdown]
# After exploring the PEN America dataset and comparing the results from each data visualization, we were able to draw the following two main conclusions in response to our primary and secondary research questions:
#
# * **The Republican party holds the most political influence over book-banning in America, comprising a cumulative 60% (14 out of 23 states), more than half of banned book locations overall.**
#   * Among the top five censorship areas, four were states located in the Southern regions of the United States. This indicates that the majority of book bans occur in The South where there is a strong presence of right-wing ideologies/beliefs. For instance, we discovered that the no. 1 place to show up at the top in both charts as a leading state in the censorship initiative was Texas, which is commonly known to the public for being openly red (affliated with the Conservative party).
#   - Interestingly enough, the state of Pennsylvania revealed the most occurrences of book censorship in schools despite showing up as blue (affiliated with the Democratic party). However, the placement of this state in the left-wing faction may be considered a potential outlier; Pennsylvania is also commonly known to the public for being more accurately classified as a swing state, meaning that it's liable to unpredictably switch between both political parties. So, while it may have had a blue designation in 2021-2022, the state could unreliably change to red in the future which would in turn make all top five censorship states congruently Republican.
#
# * **Censorship in educational institutions supersedes book bans in memory institutions across all states, but only marginally.**
#   - The most prevalent ban type in each of the top censorship states revealed itself to be Pending Book Bans which suggests that there is a continuously growing amount of books being investigated for censorship, outnumbering the amount of existing books that have already been banned.
#   - Also, contrary to common belief, libraries were the not the most popular ban type. While books Banned in Libraries was still significant (it was the third top ban), Banned in Classrooms greatly outperformed the other type of ban by ranking second only after Pending Bans. Most states had the least amount of banned book cases in both types.
#
# Ultimately, books are political because knowledge is power. Having access to information and being able to educate oneself is the single most powerful act of intellectual freedom that every person unequivocably can exercise. To disregard this inalienable right is to deny the very doctrine (S.R. Ranganathan's five laws) of library science. It is only by actively practicing these self-evident core principles as a nation that we can achieve empowerment, enlightenment, wisdom through education and access to information for all.

# %% [markdown]
# ## Potential Subtopic(s)
# * The intersectionality of censorship, such as the inaccessibility of LGBTQIA+ literature/resources in libraries and its effect on mental health.
# * Quantifying the inclusion of Black professionals, books written by Black authors, and Black stories printed in the publishing and cultural heritage industries.
# * Applying geolocation as a data mapping tool to measure the impact of censorship on small-owned businesses (e.g. bookstores) in communities of color.
# * The application of LLMs for the purpose of censorship and how it poses ethical questions about whether AI bias is present when determining which books in the data should be banned.

# %% [markdown]
# #APA Reference List
# ## Non-Profit Organizations and NGOs
#
# * American Library Association. (n.d.). Office for Intellectual Freedom. American Library Association. https://www.ala.org/advocacy/intfreedom
#
# * National Coalition Against Censorship. (n.d.). NCAC: Defending freedom of expression since 1974. https://ncac.org
#
# * PEN America. (2023). Banned in the USA: The growing movement to censor books in schools. https://pen.org/report/banned-usa-growing-movement-to-censor-books/
#
# * African American Intellectual History Society. (n.d.). AAIHS: Advancing the work of Black intellectuals. https://www.aaihs.org
#
# * We Need Diverse Books. (n.d.). WNDB mission and programs. https://diversebooks.org
#
# ##Government Sources
#
# * U.S. Census Bureau. (n.d.). Explore census data. https://data.census.gov
#
# * U.S. Department of Education, Office for Civil Rights. (2021). Civil Rights Data Collection (CRDC). https://ocrdata.ed.gov
#
# * Library of Congress. (n.d.). Banned & challenged books. https://www.loc.gov/catdir/cpso/bannedbooks.html
#
# * Federal Election Commission. (2021). 2020 presidential election results. https://www.fec.gov/introduction-campaign-finance/election-and-voting-information/
#
# #Peer-Reviewed Journal Articles
#
# * Bell, D. (2022). Book bans and Black lives: A critical race theory analysis of educational censorship. Journal of Curriculum Studies, 54(3), 415–431. https://doi.org/10.1080/00220272.2022.2042631
#
# * Garcia, M. & Weiss, E. (2021). The political economy of censorship in education. American Educational Research Journal, 58(4), 765–798. https://doi.org/10.3102/00028312211005231
#
# * Johnson, T. M. (2020). Whose knowledge gets taught? Race, censorship, and curriculum battles in the U.S. Harvard Educational Review, 90(1), 89–112. https://doi.org/10.17763/1943-5045-90.1.89
#
# * Osei, A. (2019). The erasure of Black thought in American schools. Journal of Black Studies, 50(5), 456–475. https://doi.org/10.1177/0021934719858743
#
# * Lee, R. & Robinson, K. (2020). Gatekeeping Black authors: Representation in the publishing industry. Publishing Research Quarterly, 36(4), 549–562. https://doi.org/10.1007/s12109-020-09758-5
#
# * Nguyen, T., & Jamal, H. (2023). Reading while Black: Policing literary freedom in U.S. schools. Race, Ethnicity and Education, 26(2), 215–232. https://doi.org/10.1080/13613324.2022.2086351
#
# * Parker, L., & Johnson, C. (2022). Intersecting injustices: Queer and Black narratives in the era of book bans. Gender & Society, 36(4), 565–588. https://doi.org/10.1177/08912432221098765
#
# * West, M., & Bianchi, S. (2022). Algorithms and epistemic violence: Racial bias in artificial intelligence curation. Big Data & Society, 9(2). https://doi.org/10.1177/20539517221098320
#
# * Ranganathan, S. R. (1931). The five laws of library science. Madras, India: Madras Library Association. https://babel.hathitrust.org/cgi/pt?id=uc1.$b99721&seq=13
